# %%
# Train logistic regression model with adjusted hyperparameters
log_reg_adjusted = LogisticRegression(max_iter=1000, class_weight='balanced', C=0.39)  # Adjust the value of C for regularization
log_reg_adjusted.fit(X_train_smote, y_train_smote)

# Predictions with adjusted model
y_pred_adjusted = log_reg_adjusted.predict(X_test)

# Evaluation with adjusted model
accuracy_adjusted = accuracy_score(y_test, y_pred_adjusted)
conf_matrix_adjusted = confusion_matrix(y_test, y_pred_adjusted)

# Confusion Matrix Visualization with adjusted model
plt.figure(figsize=(10, 7))
sns.heatmap(conf_matrix_adjusted, annot=True, fmt='d', cmap='Blues', xticklabels=sorted(card_categories), yticklabels=sorted(card_categories))
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix with Adjusted Hyperparameters')
plt.show()

print("Accuracy with adjusted hyperparameters: ", accuracy_adjusted)
# Out:
# Accuracy with adjusted hyperparameters:  0.8338278931750742

# %%
from imblearn.over_sampling import SMOTE

# Identify the minority classes (gold and silver categories)
minority_classes = ['Gold', 'Silver']

# Apply SMOTE to balance the classes with a focus on the minority classes
smote_oversample = SMOTE(sampling_strategy={label: 5000 for label in minority_classes}, random_state=42)
X_train_smote, y_train_smote = smote_oversample.fit_resample(X_train, y_train)

# Train logistic regression model with adjusted hyperparameters and oversampling
log_reg_adjusted_oversample = LogisticRegression(max_iter=4000, class_weight='balanced', C=0.39)
log_reg_adjusted_oversample.fit(X_train_smote, y_train_smote)

# Predictions with adjusted model and oversampling
y_pred_adjusted_oversample = log_reg_adjusted_oversample.predict(X_test)

# Evaluation with adjusted model and oversampling
accuracy_adjusted_oversample = accuracy_score(y_test, y_pred_adjusted_oversample)
conf_matrix_adjusted_oversample = confusion_matrix(y_test, y_pred_adjusted_oversample)

# Confusion Matrix Visualization with adjusted model and oversampling
plt.figure(figsize=(10, 7))
sns.heatmap(conf_matrix_adjusted_oversample, annot=True, fmt='d', cmap='Blues', xticklabels=sorted(card_categories), yticklabels=sorted(card_categories))
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix with Adjusted Hyperparameters and SMOTE Oversampling')
plt.show()

print("Accuracy with adjusted hyperparameters and SMOTE oversampling: ", accuracy_adjusted_oversample)
# Out:
# Accuracy with adjusted hyperparameters and SMOTE oversampling:  0.8318496538081108
